# %%
from moveread.core import CoreAPI
import pure_cv as vc
from haskellian import either as E
from moveread.export import game_samples

# %%
core = CoreAPI.debug('../moveread-pipelines/data/demo/core-out/')
game = (await core.games.read('a/9/4')).unsafe()
# await core.games.keys().sync()

# %%
samples = list(E.filter(await game_samples(game, api=core)))

# %%
vc.show(*[(lab, img) for img, lab in samples], ncols=2, height=1.5)
